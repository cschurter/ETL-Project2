# %%
import pandas as pd
from sqlalchemy import create_engine
# In GitBash:
# $ pip install geocoder
import geocoder
import gmaps
import numpy as np
from includes import (gmaps_api_key)
# %matplotlib inline
error_count = 0

# %%
#create function for geo coding addresses
def geomapper(address):
    #try:
        g = geocoder.google(address, key=gmaps_api_key)
        lat = g.json['lat']
        long = g.json['lng']
        return (f'{lat},{long}')
    #except:
        #error_count += 1
        #return (f'32.7778,-117.2265')

# %%
#Create function called locateAddresses that adds latitude and longitude columns for geomapping
#Assumes df have column "Address"

def locateAddresses(df):
    df["geo"] = 0
    df["geo"]= df.Address.apply(lambda x: geomapper(x))
    
    #split geo column to assign values in latitude and longitude 
    df[['Lat', 'Lng']] = df.geo.str.split(',', expand = True)
    #df = df.drop(columns=['geo'])
    del df['geo']
    return

# %%
#File 1: Events: SD_Events.csv

# %%
#Process File 1
SD_events_file = "Resources/SD_Events.csv"
SD_events_df = pd.read_csv(SD_events_file)
SD_events_df.head()
# Out:
#                                           Event  \
# 0  15th Annual Martin Luther King Jr Day Parade
# 1  18th Annual St Patricks Day Parade  Festival
# 2            3rd Annual San Diego Bird Festival
# 3    4th Annual International Mariachi Festival
# 4                   4th Annual Small Image Show
#
#                                          Description Neighborhood       Date  \
# 0                                     (Not Provided)     Downtown  1/20/2019
# 1                                     (Not Provided)  Balboa Park  3/16/2019
# 2                                     (Not Provided)  Mission Bay  5/12/2019
# 3                                     (Not Provided)    South Bay  3/10/2019
# 4  Art Exhibition Featuring Works 10x10" and Smaller     Downtown  4/21/2019
#
#   Cost
# 0   $$
# 1    $
# 2   $$
# 3   $$
# 4   $$

# %%
#Convert '$$' in Cost column to numeric
# get the length of the string of column in a dataframe
#http://www.datasciencemadesimple.com/get-string-length-column-dataframe-python-pandas/
#df['Quarters_length'] = df['Quarters'].apply(len)

SD_events_df.Cost = SD_events_df.Cost.apply(len)
SD_events_df.head()
# Out:
#                                           Event  \
# 0  15th Annual Martin Luther King Jr Day Parade
# 1  18th Annual St Patricks Day Parade  Festival
# 2            3rd Annual San Diego Bird Festival
# 3    4th Annual International Mariachi Festival
# 4                   4th Annual Small Image Show
#
#                                          Description Neighborhood       Date  \
# 0                                     (Not Provided)     Downtown  1/20/2019
# 1                                     (Not Provided)  Balboa Park  3/16/2019
# 2                                     (Not Provided)  Mission Bay  5/12/2019
# 3                                     (Not Provided)    South Bay  3/10/2019
# 4  Art Exhibition Featuring Works 10x10" and Smaller     Downtown  4/21/2019
#
#    Cost
# 0     2
# 1     1
# 2     2
# 3     2
# 4     2

# %%
#Add "Category" column with "Food and Drink in San Diego" value
SD_events_df["Category"] = "Events"
SD_events_df.head()
# Out:
#                                           Event  \
# 0  15th Annual Martin Luther King Jr Day Parade
# 1  18th Annual St Patricks Day Parade  Festival
# 2            3rd Annual San Diego Bird Festival
# 3    4th Annual International Mariachi Festival
# 4                   4th Annual Small Image Show
#
#                                          Description Neighborhood       Date  \
# 0                                     (Not Provided)     Downtown  1/20/2019
# 1                                     (Not Provided)  Balboa Park  3/16/2019
# 2                                     (Not Provided)  Mission Bay  5/12/2019
# 3                                     (Not Provided)    South Bay  3/10/2019
# 4  Art Exhibition Featuring Works 10x10" and Smaller     Downtown  4/21/2019
#
#    Cost Category
# 0     2   Events
# 1     1   Events
# 2     2   Events
# 3     2   Events
# 4     2   Events

# %%
#Find the datatypes
SD_events_df.dtypes
# Out:
# Event           object
# Description     object
# Neighborhood    object
# Date            object
# Cost             int64
# Category        object
# dtype: object

# %%
#Replace "Ongoing" value in Date column with blank to be able to change datatype of Date column 
#into a date type to be able to search and sort datafield by date
#Keepin in mind:  blank dates = NaT = "Ongoing"
SD_events_df = SD_events_df.replace({'Date':['Ongoing']},'')
SD_events_df['Date'] = pd.to_datetime(SD_events_df['Date'])

#Rename column "Event" to "Name"
SD_events_df = SD_events_df.rename(columns={"Event":"Name"})
SD_events_df.head()
# Out:
#                                            Name  \
# 0  15th Annual Martin Luther King Jr Day Parade
# 1  18th Annual St Patricks Day Parade  Festival
# 2            3rd Annual San Diego Bird Festival
# 3    4th Annual International Mariachi Festival
# 4                   4th Annual Small Image Show
#
#                                          Description Neighborhood       Date  \
# 0                                     (Not Provided)     Downtown 2019-01-20
# 1                                     (Not Provided)  Balboa Park 2019-03-16
# 2                                     (Not Provided)  Mission Bay 2019-05-12
# 3                                     (Not Provided)    South Bay 2019-03-10
# 4  Art Exhibition Featuring Works 10x10" and Smaller     Downtown 2019-04-21
#
#    Cost Category
# 0     2   Events
# 1     1   Events
# 2     2   Events
# 3     2   Events
# 4     2   Events

# %%
#Clean File 1
#Sort Dataframe by name
SD_events_df = SD_events_df.sort_values("Name")
SD_events_df.head()
# Out:
#                                            Name  \
# 0  15th Annual Martin Luther King Jr Day Parade
# 1  18th Annual St Patricks Day Parade  Festival
# 2            3rd Annual San Diego Bird Festival
# 3    4th Annual International Mariachi Festival
# 4                   4th Annual Small Image Show
#
#                                          Description Neighborhood       Date  \
# 0                                     (Not Provided)     Downtown 2019-01-20
# 1                                     (Not Provided)  Balboa Park 2019-03-16
# 2                                     (Not Provided)  Mission Bay 2019-05-12
# 3                                     (Not Provided)    South Bay 2019-03-10
# 4  Art Exhibition Featuring Works 10x10" and Smaller     Downtown 2019-04-21
#
#    Cost Category
# 0     2   Events
# 1     1   Events
# 2     2   Events
# 3     2   Events
# 4     2   Events

# %%
#File 2: Attractions: TripAdvisor.csv

# %%
#Process File 2
trip_advisor_file = "Resources/TripAdvisor.csv"
trip_advisor_df = pd.read_csv(trip_advisor_file)
trip_advisor_df.head()
# Out:
#                                      Name  \
# 0                      SeaWorld San Diego
# 1  Mt. Soledad National Veterans Memorial
# 2                     Pacific Surf School
# 3                     San Diego Fly Rides
# 4                            Belmont Park
#
#                                              Address  \
# 0      500 Sea World Drive, San Diego, CA 92109-7904
# 1  6905 La Jolla Scenic Drive South, La Jolla, Sa...
# 2        4121 Mission Blvd, San Diego, CA 92109-5028
# 3  7444 Girard Ave, La Jolla, San Diego, CA 92037...
# 4        3146 Mission Blvd, San Diego, CA 92109-7767
#
#                    Category  # of Reviews Cost
# 0              Things to do          9485  $$$
# 1              Things to do          2240    $
# 2  Boat Tours  Water Sports          1156   $$
# 3                     Tours          1113   $$
# 4              Things to do           764    $

# %%
#Convert '$$' in Cost column to numeric
# get the length of the string of column in a dataframe
#http://www.datasciencemadesimple.com/get-string-length-column-dataframe-python-pandas/
#df['Quarters_length'] = df['Quarters'].apply(len)

trip_advisor_df.Cost = trip_advisor_df.Cost.apply(len)
trip_advisor_df.head()
# Out:
#                                      Name  \
# 0                      SeaWorld San Diego
# 1  Mt. Soledad National Veterans Memorial
# 2                     Pacific Surf School
# 3                     San Diego Fly Rides
# 4                            Belmont Park
#
#                                              Address  \
# 0      500 Sea World Drive, San Diego, CA 92109-7904
# 1  6905 La Jolla Scenic Drive South, La Jolla, Sa...
# 2        4121 Mission Blvd, San Diego, CA 92109-5028
# 3  7444 Girard Ave, La Jolla, San Diego, CA 92037...
# 4        3146 Mission Blvd, San Diego, CA 92109-7767
#
#                    Category  # of Reviews  Cost
# 0              Things to do          9485     3
# 1              Things to do          2240     1
# 2  Boat Tours  Water Sports          1156     2
# 3                     Tours          1113     2
# 4              Things to do           764     1

# %%
#Replace "# of Reviews" column to "Reviews"
trip_advisor_df = trip_advisor_df.rename(columns={"# of Reviews":"Reviews"})
#Convert "Reviews" datatype to int 
trip_advisor_df['Reviews'] = trip_advisor_df['Reviews'].astype('int')
trip_advisor_df.head()
# Out:
#                                      Name  \
# 0                      SeaWorld San Diego
# 1  Mt. Soledad National Veterans Memorial
# 2                     Pacific Surf School
# 3                     San Diego Fly Rides
# 4                            Belmont Park
#
#                                              Address  \
# 0      500 Sea World Drive, San Diego, CA 92109-7904
# 1  6905 La Jolla Scenic Drive South, La Jolla, Sa...
# 2        4121 Mission Blvd, San Diego, CA 92109-5028
# 3  7444 Girard Ave, La Jolla, San Diego, CA 92037...
# 4        3146 Mission Blvd, San Diego, CA 92109-7767
#
#                    Category  Reviews  Cost
# 0              Things to do     9485     3
# 1              Things to do     2240     1
# 2  Boat Tours  Water Sports     1156     2
# 3                     Tours     1113     2
# 4              Things to do      764     1

# %%
#get a list of the Category
category_list = trip_advisor_df["Category"].unique()
category_list = pd.DataFrame(category_list)
category_list.columns = ["Category List"]

#Sort Dataframe by Category List
category_list = category_list.sort_values("Category List")
category_list
# Out:
#                Category List
# 1   Boat Tours  Water Sports
# 4         Classes  Workshops
# 10           Concerts  Shows
# 3                Food  Drink
# 5                 Fun  Games
# 6                  Nightlife
# 7         Outdoor Activities
# 9                   Shopping
# 8             Spas  Wellness
# 0               Things to do
# 2                      Tours
# 11            Transportation

# %%
trip_advisor_df = trip_advisor_df.replace({'Category':['Boat Tours  Water Sports']},\
                                                'Boat Tours & Water Sports')

trip_advisor_df = trip_advisor_df.replace({'Category':['Classes  Workshops']},\
                                                'Classes & Workshops')

trip_advisor_df = trip_advisor_df.replace({'Category':['Concerts  Shows']},\
                                                'Concerts & Shows')

trip_advisor_df = trip_advisor_df.replace({'Category':['Food  Drink']},\
                                                'Food & Drink')

trip_advisor_df = trip_advisor_df.replace({'Category':['Fun  Games']},\
                                                'Fun & Games')

trip_advisor_df = trip_advisor_df.replace({'Category':['Spas  Wellness']},\
                                                'Spas & Wellness')

trip_advisor_df.head()
# Out:
#                                      Name  \
# 0                      SeaWorld San Diego
# 1  Mt. Soledad National Veterans Memorial
# 2                     Pacific Surf School
# 3                     San Diego Fly Rides
# 4                            Belmont Park
#
#                                              Address  \
# 0      500 Sea World Drive, San Diego, CA 92109-7904
# 1  6905 La Jolla Scenic Drive South, La Jolla, Sa...
# 2        4121 Mission Blvd, San Diego, CA 92109-5028
# 3  7444 Girard Ave, La Jolla, San Diego, CA 92037...
# 4        3146 Mission Blvd, San Diego, CA 92109-7767
#
#                     Category  Reviews  Cost
# 0               Things to do     9485     3
# 1               Things to do     2240     1
# 2  Boat Tours & Water Sports     1156     2
# 3                      Tours     1113     2
# 4               Things to do      764     1

# %%
#get new list of the Category to see changes
category_list = trip_advisor_df["Category"].unique()
category_list = pd.DataFrame(category_list)
category_list.columns = ["Category List"]

#Sort Dataframe by Category List
category_list = category_list.sort_values("Category List")
category_list
# Out:
#                 Category List
# 1   Boat Tours & Water Sports
# 4         Classes & Workshops
# 10           Concerts & Shows
# 3                Food & Drink
# 5                 Fun & Games
# 6                   Nightlife
# 7          Outdoor Activities
# 9                    Shopping
# 8             Spas & Wellness
# 0                Things to do
# 2                       Tours
# 11             Transportation

# %%
#Clean File 2
#Sort Dataframe by name
trip_advisor_df = trip_advisor_df.sort_values("Name")
trip_advisor_df.head()
# Out:
#                           Name  \
# 58        Action Sport Rentals
# 79      Adventure Water Sports
# 130     Adventure Water Sports
# 127   Affordable Jet Ski Tours
# 77   Always Summer Surf School
#
#                                                Address  \
# 58         3981 Mission Blvd, San Diego, CA 92109-6958
# 79   1710 W Mission Bay Dr Dana Hotel, San Diego, C...
# 130    2211 Pacific Beach Dr, San Diego, CA 92109-5626
# 127      4255 Mission Bay Dr, San Diego, CA 92109-5782
# 77           4904 Crystal Dr, San Diego, CA 92109-2062
#
#                       Category  Reviews  Cost
# 58   Boat Tours & Water Sports       18     2
# 79   Boat Tours & Water Sports        7     2
# 130  Boat Tours & Water Sports        1     2
# 127  Boat Tours & Water Sports        1     2
# 77   Boat Tours & Water Sports        8     2

# %%
#File 3: Restaurants: Yelp_restaurants.csv

# %%
#Process File 3
yelp_file = "Resources/Yelp_restaurants.csv"
yelp_df = pd.read_csv(yelp_file)
yelp_df.head()
# Out:
#                                Name            Address            Category  \
# 0             Daybreak Island Grill      2296 Bacon St  Breakfast & Brunch
# 1  Bravo's Mexican Bistro & Cantina   5001 Newport Ave             Mexican
# 2                     Caveman Pizza   1404 Vacation Rd               Pizza
# 3              Barefoot Bar & Grill   1404 Vacation Rd      American (New)
# 4                           Saska's  3768 Mission Blvd         Steakhouses
#
#    # of Reviews  Cost
# 0          5111    $$
# 1          3054    $$
# 2          2594    $$
# 3          1526   $$$
# 4          1501  $$$$

# %%
#Convert '$$' in Cost column to numeric
# get the length of the string of column in a dataframe
#http://www.datasciencemadesimple.com/get-string-length-column-dataframe-python-pandas/
#df['Quarters_length'] = df['Quarters'].apply(len)

yelp_df.Cost = yelp_df.Cost.apply(len)
yelp_df.head()
# Out:
#                                Name            Address            Category  \
# 0             Daybreak Island Grill      2296 Bacon St  Breakfast & Brunch
# 1  Bravo's Mexican Bistro & Cantina   5001 Newport Ave             Mexican
# 2                     Caveman Pizza   1404 Vacation Rd               Pizza
# 3              Barefoot Bar & Grill   1404 Vacation Rd      American (New)
# 4                           Saska's  3768 Mission Blvd         Steakhouses
#
#    # of Reviews  Cost
# 0          5111     2
# 1          3054     2
# 2          2594     2
# 3          1526     3
# 4          1501     4

# %%
#add city and state in Addres to complete the address for geomapping 
yelp_df['Address'] = yelp_df.loc[:,["Address"]] + ", San Diego CA"
yelp_df.head()
# Out:
#                                Name                          Address  \
# 0             Daybreak Island Grill      2296 Bacon St, San Diego CA
# 1  Bravo's Mexican Bistro & Cantina   5001 Newport Ave, San Diego CA
# 2                     Caveman Pizza   1404 Vacation Rd, San Diego CA
# 3              Barefoot Bar & Grill   1404 Vacation Rd, San Diego CA
# 4                           Saska's  3768 Mission Blvd, San Diego CA
#
#              Category  # of Reviews  Cost
# 0  Breakfast & Brunch          5111     2
# 1             Mexican          3054     2
# 2               Pizza          2594     2
# 3      American (New)          1526     3
# 4         Steakhouses          1501     4

# %%
#Rename "# of Reviews" column to "Reviews"
yelp_df = yelp_df.rename(columns={"# of Reviews":"Reviews"})
#Convert "Reviews" datatype to int 
yelp_df['Reviews'] = yelp_df['Reviews'].astype('int')
yelp_df.head()
# Out:
#                                Name                          Address  \
# 0             Daybreak Island Grill      2296 Bacon St, San Diego CA
# 1  Bravo's Mexican Bistro & Cantina   5001 Newport Ave, San Diego CA
# 2                     Caveman Pizza   1404 Vacation Rd, San Diego CA
# 3              Barefoot Bar & Grill   1404 Vacation Rd, San Diego CA
# 4                           Saska's  3768 Mission Blvd, San Diego CA
#
#              Category  Reviews  Cost
# 0  Breakfast & Brunch     5111     2
# 1             Mexican     3054     2
# 2               Pizza     2594     2
# 3      American (New)     1526     3
# 4         Steakhouses     1501     4

# %%
#Rename "Category" column to "Description" column
yelp_df = yelp_df.rename(columns = {"Category": "Description"})

#Add "Category" column with "Food and Drink in San Diego" value
yelp_df["Category"] = "Food & Drink"
yelp_df.head()
# Out:
#                                Name                          Address  \
# 0             Daybreak Island Grill      2296 Bacon St, San Diego CA
# 1  Bravo's Mexican Bistro & Cantina   5001 Newport Ave, San Diego CA
# 2                     Caveman Pizza   1404 Vacation Rd, San Diego CA
# 3              Barefoot Bar & Grill   1404 Vacation Rd, San Diego CA
# 4                           Saska's  3768 Mission Blvd, San Diego CA
#
#           Description  Reviews  Cost      Category
# 0  Breakfast & Brunch     5111     2  Food & Drink
# 1             Mexican     3054     2  Food & Drink
# 2               Pizza     2594     2  Food & Drink
# 3      American (New)     1526     3  Food & Drink
# 4         Steakhouses     1501     4  Food & Drink

# %%
#Clean File 3 
yelp_df = yelp_df[["Name", "Description", "Address", "Category", "Reviews", "Cost"]]

#Sort Dataframe by name
yelp_df.sort_values("Name")
yelp_df.head()
# Out:
#                                Name         Description  \
# 0             Daybreak Island Grill  Breakfast & Brunch
# 1  Bravo's Mexican Bistro & Cantina             Mexican
# 2                     Caveman Pizza               Pizza
# 3              Barefoot Bar & Grill      American (New)
# 4                           Saska's         Steakhouses
#
#                            Address      Category  Reviews  Cost
# 0      2296 Bacon St, San Diego CA  Food & Drink     5111     2
# 1   5001 Newport Ave, San Diego CA  Food & Drink     3054     2
# 2   1404 Vacation Rd, San Diego CA  Food & Drink     2594     2
# 3   1404 Vacation Rd, San Diego CA  Food & Drink     1526     3
# 4  3768 Mission Blvd, San Diego CA  Food & Drink     1501     4

# %%
#Add latitude and longitude data to all files
yelp_df = yelp_df
locateAddresses(yelp_df)
print(error_count)
yelp_df.head()
# Out:
# 0
#                                Name         Description  \
# 0             Daybreak Island Grill  Breakfast & Brunch
# 1  Bravo's Mexican Bistro & Cantina             Mexican
# 2                     Caveman Pizza               Pizza
# 3              Barefoot Bar & Grill      American (New)
# 4                           Saska's         Steakhouses
#
#                            Address      Category  Reviews  Cost         Lat  \
# 0      2296 Bacon St, San Diego CA  Food & Drink     5111     2  32.7532822
# 1   5001 Newport Ave, San Diego CA  Food & Drink     3054     2  32.7467997
# 2   1404 Vacation Rd, San Diego CA  Food & Drink     2594     2  32.7741456
# 3   1404 Vacation Rd, San Diego CA  Food & Drink     1526     3  32.7741456
# 4  3768 Mission Blvd, San Diego CA  Food & Drink     1501     4  32.7839428
#
#             Lng
# 0  -117.2457722
# 1  -117.2513299
# 2  -117.2404383
# 3  -117.2404383
# 4  -117.2529375

# %%
#Convert query result to a csv file and use that file to drag and drop into a google map app to show the locations in the map.
yelp_df.to_csv('yelpLatLong.csv', index=False, header=False)

# %%
#Add latitude and longitude columns for gmapping using the locateAddresses function
locateAddresses(trip_advisor_df)
print(error_count)
trip_advisor_df.head()
# Out:
# Status code Unknown from https://maps.googleapis.com/maps/api/geocode/json: ERROR - HTTPSConnectionPool(host='maps.googleapis.com', port=443): Read timed out. (read timeout=5.0)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-2f1ee23b3fc2> in <module>()
#       1 #Add latitude and longitude columns for gmapping using the locateAddresses function
# ----> 2 locateAddresses(trip_advisor_df)
#       3 print(error_count)
#       4 trip_advisor_df.head()
#
# <ipython-input-3-5281f3c8d347> in locateAddresses(df)
#       4 def locateAddresses(df):
#       5     df["geo"] = 0
# ----> 6     df["geo"]= df.Address.apply(lambda x: geomapper(x))
#       7
#       8     #split geo column to assign values in latitude and longitude
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-3-5281f3c8d347> in <lambda>(x)
#       4 def locateAddresses(df):
#       5     df["geo"] = 0
# ----> 6     df["geo"]= df.Address.apply(lambda x: geomapper(x))
#       7
#       8     #split geo column to assign values in latitude and longitude
#
# <ipython-input-2-b0141c4dac33> in geomapper(address)
#       3     #try:
#       4         g = geocoder.google(address, key=gmaps_api_key)
# ----> 5         lat = g.json['lat']
#       6         long = g.json['lng']
#       7         return (f'{lat},{long}')
#
# TypeError: 'NoneType' object is not subscriptable

# %%
SD_events_file = "Resources/SD_Events.csv"
SD_events_df = pd.read_csv(tirpadvisorLatLong.csv)
SD_events_df.head()

# %%
#Convert query result to a csv file and use that file to drag and drop into a google map app to show the locations in the map.
trip_advisor_df.to_csv('tirpadvisorLatLong.csv', index=False, header=False)

# %%
#Create database connection
connection_string = "root:Password@localhost/trip_planner_db?charset=utf8"
engine = create_engine(f'mysql://{connection_string}')

# %%
# Confirm tables
engine.table_names()

# %%
#Delete all rows from the table and resets auto increment value for id to 1
engine.execute("TRUNCATE TABLE events;")
engine.execute("TRUNCATE TABLE attractions;")
engine.execute("TRUNCATE TABLE restaurants;")

# %%
#Load DataFrames into database
SD_events_df.to_sql(name='events', con=engine, if_exists='append', index=False)
trip_advisor_df.to_sql(name='attractions', con=engine, if_exists='append', index=False)
yelp_df.to_sql(name='restaurants', con=engine, if_exists='append', index=False)

# %%
#Test Queries

# %%
#Select from all tables all events, attractions and restaurants with cost range of 2 and 3.
expensive_activities_df = pd.read_sql_query('select * from (select * from events union select * from attractions union select * from restaurants) as a \
where a.Cost = 3 AND a.Address IS NOT NULL order by a.Category;', con=engine)
#locateAddresses(expensive_activities_df)
expensive_activities_df

# %%
# Configure gmaps with API key
gmaps.configure(api_key=gmaps_api_key)

# Store 'Lat' and 'Lng' into  locations 
locations = expensive_activities_df[["Lat", "Lng"]].astype(float)
print(locations)
reviews = expensive_activities_df["Reviews"].astype(float)
print(reviews)

# %%
# From gitbash, you may have to run the following, then restart Jupyter if no map displays:
# $ pip install gmaps
# $ jupyter nbextension enable --py --sys-prefix gmaps
# $ jupyter nbextension enable --py widgetsnbextension

# Create a Heatmap layer
san_diego_coordinates = (32.7839428,-117.2529375)
fig = gmaps.figure(center=san_diego_coordinates, zoom_level=13)
#fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=reviews, 
                                 dissipating=False, max_intensity=1500,
                                 point_radius = .01)

# Adjust heat_layer setting to help with heatmap dissipating on zoom
heat_layer.dissipating = False
# Intensity based on maximum value in the 'weights' parameter
heat_layer.max_intensity = 1500
# point_radius is based in km, I think
heat_layer.point_radius = .01

fig.add_layer(heat_layer)

fig

# %%
#Convert query result to a csv file and use that file to drag and drop into a google map app to show the locations in the map.
expensive_activities_df.to_csv('query_results.csv', index=False, header=False)

# %%
#To show Name, Address and review count if you click one of the red dots
review_rate = expensive_activities_df.loc[:,['Reviews', 'Name', 'Address']].values.tolist()

events_layer = gmaps.symbol_layer(
    locations, fill_color='rgba(200, 200, 200, 0.4)',
    stroke_color='rgba(250, 0, 0, 0.4)', scale=4,
    #info_box_content=[f"Review Count: {review}" for review in review_rate]
    info_box_content=[f"{review[1]}, {review[2]}, Reviews: {review[0]}" for review in review_rate]
    
)


fig = gmaps.figure()
fig.add_layer(events_layer)

fig

# %% [raw]
# #Confirm data has been added by querying the events, attractions and restaurants tables
# pd.read_sql_query('select * from events union select * from attractions union select * from restaurants\
#     order by Name;', con=engine).head()

# %%
pd.read_sql_query('select * from (select * from events union select * from attractions union select * from restaurants) as a \
where a.Category = "Food & Drink" order by a.Name;', con=engine).head()
