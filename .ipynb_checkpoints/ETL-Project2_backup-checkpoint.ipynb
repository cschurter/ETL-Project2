# %%
import pandas as pd
from sqlalchemy import create_engine
import gmaps
import numpy as np

# %%
#File 1: Events: SD_Events.csv

# %%
#Process File 1
SD_events_file = "Resources/SD_Events.csv"
SD_events_df = pd.read_csv(SD_events_file)
SD_events_df.head()
# Out:
#                                           Event  \
# 0  15th Annual Martin Luther King Jr Day Parade
# 1  18th Annual St Patricks Day Parade  Festival
# 2            3rd Annual San Diego Bird Festival
# 3    4th Annual International Mariachi Festival
# 4                   4th Annual Small Image Show
#
#                                          Description Neighborhood       Date  \
# 0                                     (Not Provided)     Downtown  1/20/2019
# 1                                     (Not Provided)  Balboa Park  3/16/2019
# 2                                     (Not Provided)  Mission Bay  5/12/2019
# 3                                     (Not Provided)    South Bay  3/10/2019
# 4  Art Exhibition Featuring Works 10x10" and Smaller     Downtown  4/21/2019
#
#   Cost
# 0   $$
# 1    $
# 2   $$
# 3   $$
# 4   $$

# %%
#Convert '$$' in Cost column to numeric
# get the length of the string of column in a dataframe
#http://www.datasciencemadesimple.com/get-string-length-column-dataframe-python-pandas/
#df['Quarters_length'] = df['Quarters'].apply(len)

SD_events_df.Cost = SD_events_df.Cost.apply(len)
SD_events_df.head()
# Out:
#                                           Event  \
# 0  15th Annual Martin Luther King Jr Day Parade
# 1  18th Annual St Patricks Day Parade  Festival
# 2            3rd Annual San Diego Bird Festival
# 3    4th Annual International Mariachi Festival
# 4                   4th Annual Small Image Show
#
#                                          Description Neighborhood       Date  \
# 0                                     (Not Provided)     Downtown  1/20/2019
# 1                                     (Not Provided)  Balboa Park  3/16/2019
# 2                                     (Not Provided)  Mission Bay  5/12/2019
# 3                                     (Not Provided)    South Bay  3/10/2019
# 4  Art Exhibition Featuring Works 10x10" and Smaller     Downtown  4/21/2019
#
#    Cost
# 0     2
# 1     1
# 2     2
# 3     2
# 4     2

# %%
#Add "Category" column with "Food and Drink in San Diego" value
SD_events_df["Category"] = "Events"
SD_events_df.head()
# Out:
#                                           Event  \
# 0  15th Annual Martin Luther King Jr Day Parade
# 1  18th Annual St Patricks Day Parade  Festival
# 2            3rd Annual San Diego Bird Festival
# 3    4th Annual International Mariachi Festival
# 4                   4th Annual Small Image Show
#
#                                          Description Neighborhood       Date  \
# 0                                     (Not Provided)     Downtown  1/20/2019
# 1                                     (Not Provided)  Balboa Park  3/16/2019
# 2                                     (Not Provided)  Mission Bay  5/12/2019
# 3                                     (Not Provided)    South Bay  3/10/2019
# 4  Art Exhibition Featuring Works 10x10" and Smaller     Downtown  4/21/2019
#
#    Cost Category
# 0     2   Events
# 1     1   Events
# 2     2   Events
# 3     2   Events
# 4     2   Events

# %%
#Find the datatypes
SD_events_df.dtypes
# Out:
# Event           object
# Description     object
# Neighborhood    object
# Date            object
# Cost             int64
# Category        object
# dtype: object

# %%
#Replace "Ongoing" value in Date column with blank to be able to change datatype of Date column 
#into a date type to be able to search and sort datafield by date
#Keepin in mind:  blank dates = NaT = "Ongoing"
SD_events_df = SD_events_df.replace({'Date':['Ongoing']},'')
SD_events_df['Date'] = pd.to_datetime(SD_events_df['Date'])

#Rename column "Event" to "Name"
SD_events_df = SD_events_df.rename(columns={"Event":"Name"})
SD_events_df.head()
# Out:
#                                            Name  \
# 0  15th Annual Martin Luther King Jr Day Parade
# 1  18th Annual St Patricks Day Parade  Festival
# 2            3rd Annual San Diego Bird Festival
# 3    4th Annual International Mariachi Festival
# 4                   4th Annual Small Image Show
#
#                                          Description Neighborhood       Date  \
# 0                                     (Not Provided)     Downtown 2019-01-20
# 1                                     (Not Provided)  Balboa Park 2019-03-16
# 2                                     (Not Provided)  Mission Bay 2019-05-12
# 3                                     (Not Provided)    South Bay 2019-03-10
# 4  Art Exhibition Featuring Works 10x10" and Smaller     Downtown 2019-04-21
#
#    Cost Category
# 0     2   Events
# 1     1   Events
# 2     2   Events
# 3     2   Events
# 4     2   Events

# %%
#Clean File 1
#Sort Dataframe by name
SD_events_df = SD_events_df.sort_values("Name")
SD_events_df.head()
# Out:
#                                            Name  \
# 0  15th Annual Martin Luther King Jr Day Parade
# 1  18th Annual St Patricks Day Parade  Festival
# 2            3rd Annual San Diego Bird Festival
# 3    4th Annual International Mariachi Festival
# 4                   4th Annual Small Image Show
#
#                                          Description Neighborhood       Date  \
# 0                                     (Not Provided)     Downtown 2019-01-20
# 1                                     (Not Provided)  Balboa Park 2019-03-16
# 2                                     (Not Provided)  Mission Bay 2019-05-12
# 3                                     (Not Provided)    South Bay 2019-03-10
# 4  Art Exhibition Featuring Works 10x10" and Smaller     Downtown 2019-04-21
#
#    Cost Category
# 0     2   Events
# 1     1   Events
# 2     2   Events
# 3     2   Events
# 4     2   Events

# %%
#File 2: Attractions: TripAdvisor.csv

# %%
#Process File 2
trip_advisor_file = "Resources/TripAdvisor.csv"
trip_advisor_df = pd.read_csv(trip_advisor_file)
trip_advisor_df.head()
# Out:
#                                      Name  \
# 0                      SeaWorld San Diego
# 1  Mt. Soledad National Veterans Memorial
# 2                     Pacific Surf School
# 3                     San Diego Fly Rides
# 4                            Belmont Park
#
#                                              Address  \
# 0      500 Sea World Drive, San Diego, CA 92109-7904
# 1  6905 La Jolla Scenic Drive South, La Jolla, Sa...
# 2        4121 Mission Blvd, San Diego, CA 92109-5028
# 3  7444 Girard Ave, La Jolla, San Diego, CA 92037...
# 4        3146 Mission Blvd, San Diego, CA 92109-7767
#
#                    Category  # of Reviews Cost
# 0              Things to do          9485  $$$
# 1              Things to do          2240    $
# 2  Boat Tours  Water Sports          1156   $$
# 3                     Tours          1113   $$
# 4              Things to do           764    $

# %%
#Convert '$$' in Cost column to numeric
# get the length of the string of column in a dataframe
#http://www.datasciencemadesimple.com/get-string-length-column-dataframe-python-pandas/
#df['Quarters_length'] = df['Quarters'].apply(len)

trip_advisor_df.Cost = trip_advisor_df.Cost.apply(len)
trip_advisor_df.head()
# Out:
#                                      Name  \
# 0                      SeaWorld San Diego
# 1  Mt. Soledad National Veterans Memorial
# 2                     Pacific Surf School
# 3                     San Diego Fly Rides
# 4                            Belmont Park
#
#                                              Address  \
# 0      500 Sea World Drive, San Diego, CA 92109-7904
# 1  6905 La Jolla Scenic Drive South, La Jolla, Sa...
# 2        4121 Mission Blvd, San Diego, CA 92109-5028
# 3  7444 Girard Ave, La Jolla, San Diego, CA 92037...
# 4        3146 Mission Blvd, San Diego, CA 92109-7767
#
#                    Category  # of Reviews  Cost
# 0              Things to do          9485     3
# 1              Things to do          2240     1
# 2  Boat Tours  Water Sports          1156     2
# 3                     Tours          1113     2
# 4              Things to do           764     1

# %%
#Replace "# of Reviews" column to "Reviews"
trip_advisor_df = trip_advisor_df.rename(columns={"# of Reviews":"Reviews"})
#Convert "Reviews" datatype to int 
trip_advisor_df['Reviews'] = trip_advisor_df['Reviews'].astype('int')
trip_advisor_df.head()
# Out:
#                                      Name  \
# 0                      SeaWorld San Diego
# 1  Mt. Soledad National Veterans Memorial
# 2                     Pacific Surf School
# 3                     San Diego Fly Rides
# 4                            Belmont Park
#
#                                              Address  \
# 0      500 Sea World Drive, San Diego, CA 92109-7904
# 1  6905 La Jolla Scenic Drive South, La Jolla, Sa...
# 2        4121 Mission Blvd, San Diego, CA 92109-5028
# 3  7444 Girard Ave, La Jolla, San Diego, CA 92037...
# 4        3146 Mission Blvd, San Diego, CA 92109-7767
#
#                    Category  Reviews  Cost
# 0              Things to do     9485     3
# 1              Things to do     2240     1
# 2  Boat Tours  Water Sports     1156     2
# 3                     Tours     1113     2
# 4              Things to do      764     1

# %%
#get a list of the Category
category_list = trip_advisor_df["Category"].unique()
category_list = pd.DataFrame(category_list)
category_list.columns = ["Category List"]

#Sort Dataframe by Category List
category_list = category_list.sort_values("Category List")
category_list
# Out:
#                Category List
# 1   Boat Tours  Water Sports
# 4         Classes  Workshops
# 10           Concerts  Shows
# 3                Food  Drink
# 5                 Fun  Games
# 6                  Nightlife
# 7         Outdoor Activities
# 9                   Shopping
# 8             Spas  Wellness
# 0               Things to do
# 2                      Tours
# 11            Transportation

# %%
trip_advisor_df = trip_advisor_df.replace({'Category':['Boat Tours  Water Sports']},\
                                                'Boat Tours & Water Sports')

trip_advisor_df = trip_advisor_df.replace({'Category':['Classes  Workshops']},\
                                                'Classes & Workshops')

trip_advisor_df = trip_advisor_df.replace({'Category':['Concerts  Shows']},\
                                                'Concerts & Shows')

trip_advisor_df = trip_advisor_df.replace({'Category':['Food  Drink']},\
                                                'Food & Drink')

trip_advisor_df = trip_advisor_df.replace({'Category':['Fun  Games']},\
                                                'Fun & Games')

trip_advisor_df = trip_advisor_df.replace({'Category':['Spas  Wellness']},\
                                                'Spas & Wellness')

trip_advisor_df.head()
# Out:
#                                      Name  \
# 0                      SeaWorld San Diego
# 1  Mt. Soledad National Veterans Memorial
# 2                     Pacific Surf School
# 3                     San Diego Fly Rides
# 4                            Belmont Park
#
#                                              Address  \
# 0      500 Sea World Drive, San Diego, CA 92109-7904
# 1  6905 La Jolla Scenic Drive South, La Jolla, Sa...
# 2        4121 Mission Blvd, San Diego, CA 92109-5028
# 3  7444 Girard Ave, La Jolla, San Diego, CA 92037...
# 4        3146 Mission Blvd, San Diego, CA 92109-7767
#
#                     Category  Reviews  Cost
# 0               Things to do     9485     3
# 1               Things to do     2240     1
# 2  Boat Tours & Water Sports     1156     2
# 3                      Tours     1113     2
# 4               Things to do      764     1

# %%
#get new list of the Category to see changes
category_list = trip_advisor_df["Category"].unique()
category_list = pd.DataFrame(category_list)
category_list.columns = ["Category List"]

#Sort Dataframe by Category List
category_list = category_list.sort_values("Category List")
category_list
# Out:
#                 Category List
# 1   Boat Tours & Water Sports
# 4         Classes & Workshops
# 10           Concerts & Shows
# 3                Food & Drink
# 5                 Fun & Games
# 6                   Nightlife
# 7          Outdoor Activities
# 9                    Shopping
# 8             Spas & Wellness
# 0                Things to do
# 2                       Tours
# 11             Transportation

# %%
#Clean File 2
#Sort Dataframe by name
trip_advisor_df = trip_advisor_df.sort_values("Name")
trip_advisor_df.head()
# Out:
#                           Name  \
# 58        Action Sport Rentals
# 79      Adventure Water Sports
# 130     Adventure Water Sports
# 127   Affordable Jet Ski Tours
# 77   Always Summer Surf School
#
#                                                Address  \
# 58         3981 Mission Blvd, San Diego, CA 92109-6958
# 79   1710 W Mission Bay Dr Dana Hotel, San Diego, C...
# 130    2211 Pacific Beach Dr, San Diego, CA 92109-5626
# 127      4255 Mission Bay Dr, San Diego, CA 92109-5782
# 77           4904 Crystal Dr, San Diego, CA 92109-2062
#
#                       Category  Reviews  Cost
# 58   Boat Tours & Water Sports       18     2
# 79   Boat Tours & Water Sports        7     2
# 130  Boat Tours & Water Sports        1     2
# 127  Boat Tours & Water Sports        1     2
# 77   Boat Tours & Water Sports        8     2

# %%
#File 3: Restaurants: Yelp_restaurants.csv

# %%
#Process File 3
yelp_file = "Resources/Yelp_restaurants.csv"
yelp_df = pd.read_csv(yelp_file)
yelp_df.head()
# Out:
#                                Name            Address            Category  \
# 0             Daybreak Island Grill      2296 Bacon St  Breakfast & Brunch
# 1  Bravo's Mexican Bistro & Cantina   5001 Newport Ave             Mexican
# 2                     Caveman Pizza   1404 Vacation Rd               Pizza
# 3              Barefoot Bar & Grill   1404 Vacation Rd      American (New)
# 4                           Saska's  3768 Mission Blvd         Steakhouses
#
#    # of Reviews  Cost
# 0          5111    $$
# 1          3054    $$
# 2          2594    $$
# 3          1526   $$$
# 4          1501  $$$$

# %%
#Convert '$$' in Cost column to numeric
# get the length of the string of column in a dataframe
#http://www.datasciencemadesimple.com/get-string-length-column-dataframe-python-pandas/
#df['Quarters_length'] = df['Quarters'].apply(len)

yelp_df.Cost = yelp_df.Cost.apply(len)
yelp_df.head()
# Out:
#                                Name            Address            Category  \
# 0             Daybreak Island Grill      2296 Bacon St  Breakfast & Brunch
# 1  Bravo's Mexican Bistro & Cantina   5001 Newport Ave             Mexican
# 2                     Caveman Pizza   1404 Vacation Rd               Pizza
# 3              Barefoot Bar & Grill   1404 Vacation Rd      American (New)
# 4                           Saska's  3768 Mission Blvd         Steakhouses
#
#    # of Reviews  Cost
# 0          5111     2
# 1          3054     2
# 2          2594     2
# 3          1526     3
# 4          1501     4

# %%
#Rename "# of Reviews" column to "Reviews"
yelp_df = yelp_df.rename(columns={"# of Reviews":"Reviews"})
#Convert "Reviews" datatype to int 
yelp_df['Reviews'] = yelp_df['Reviews'].astype('int')
yelp_df.head()
# Out:
#                                Name            Address            Category  \
# 0             Daybreak Island Grill      2296 Bacon St  Breakfast & Brunch
# 1  Bravo's Mexican Bistro & Cantina   5001 Newport Ave             Mexican
# 2                     Caveman Pizza   1404 Vacation Rd               Pizza
# 3              Barefoot Bar & Grill   1404 Vacation Rd      American (New)
# 4                           Saska's  3768 Mission Blvd         Steakhouses
#
#    Reviews  Cost
# 0     5111     2
# 1     3054     2
# 2     2594     2
# 3     1526     3
# 4     1501     4

# %%
#Rename "Category" column to "Description" column
yelp_df = yelp_df.rename(columns = {"Category": "Description"})

#Add "Category" column with "Food and Drink in San Diego" value
yelp_df["Category"] = "Food & Drink"
yelp_df.head()
# Out:
#                                Name            Address         Description  \
# 0             Daybreak Island Grill      2296 Bacon St  Breakfast & Brunch
# 1  Bravo's Mexican Bistro & Cantina   5001 Newport Ave             Mexican
# 2                     Caveman Pizza   1404 Vacation Rd               Pizza
# 3              Barefoot Bar & Grill   1404 Vacation Rd      American (New)
# 4                           Saska's  3768 Mission Blvd         Steakhouses
#
#    Reviews  Cost      Category
# 0     5111     2  Food & Drink
# 1     3054     2  Food & Drink
# 2     2594     2  Food & Drink
# 3     1526     3  Food & Drink
# 4     1501     4  Food & Drink

# %%
#Clean File 3 
yelp_df = yelp_df[["Name", "Description", "Address", "Category", "Reviews", "Cost"]]

#Sort Dataframe by name
yelp_df = yelp_df.sort_values("Name")
yelp_df.head()
# Out:
#                      Name     Description                 Address  \
# 37         Arslan's Gyros           Greek       3861 Mission Blvd
# 91  BBQ House Bar & Grill            Bars        5025 Newport Ave
# 98  BO-beau kitchen + bar          French  4996 W Point Loma Blvd
# 86              Bao Beach    Asian Fusion       3735 Mission Blvd
# 3    Barefoot Bar & Grill  American (New)        1404 Vacation Rd
#
#         Category  Reviews  Cost
# 37  Food & Drink      322     2
# 91  Food & Drink       23     2
# 98  Food & Drink        6     4
# 86  Food & Drink       36     2
# 3   Food & Drink     1526     3

# %%
#Create database connection
connection_string = "root:Password@localhost/trip_planner_db?charset=utf8"
engine = create_engine(f'mysql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['attractions', 'events', 'restaurants']

# %%
#Delete all rows from the table and resets auto increment value for id to 1
engine.execute("TRUNCATE TABLE events;")
engine.execute("TRUNCATE TABLE attractions;")
engine.execute("TRUNCATE TABLE restaurants;")

# %%
#Load DataFrames into database
SD_events_df.to_sql(name='events', con=engine, if_exists='append', index=False)
trip_advisor_df.to_sql(name='attractions', con=engine, if_exists='append', index=False)
yelp_df.to_sql(name='restaurants', con=engine, if_exists='append', index=False)

# %%
#Test Queries

# %%
#Select from all tables all events, attractions and restaurants with cost range of 2 and 3.
pd.read_sql_query('select * from (select * from events union select * from attractions union select * from restaurants) as a \
where a.Cost = 2 or a.Cost = 3 order by Category;', con=engine)
# Out:
#       id                                          Name  \
# 0     94                           Paskowitz Surf Camp
# 1    106           San Diego Boat and Sailing Charters
# 2     86                                  PB Surf Shop
# 3     21                        Brothers Sport Fishing
# 4    128                       Tailwalker Sportfishing
# 5     44        Great News Cookware and Cooking School
# 6     87                        Pacifi Beach Surf Shop
# 7    109                             Intimate Miracles
# 8     12                                   ASD Morning
# 9     94                         Half Day Coastal Tour
# 10   185                      San Diego Caffeine Crawl
# 11    79                    For the Love of Art Brunch
# 12   170  Partee Place at Hilton La Jolla Torrey Pines
# 13    64          Exhibition Convergence  A Group Show
# 14   260                Valentines Day Dinner at Tidal
# 15   154                                 Night Fishing
# 16    49                                 Circle of Art
# 17   245                         The LEGO® Movie™ Days
# 18   139                               MakeIt Workshop
# 19    34                        Brewbies Beer Festival
# 20   230                 Swift Boats at War in Vietnam
# 21   124                   La Jolla Concours DElegance
# 22    18  An Evening of Middle Eastern Classical Music
# 23   215                          Sebastian Maniscalco
# 24   180              San Diego Bay Wine Food Festival
# 25    74                                Fiesta del Sol
# 26   271                                Were You There
# 27   165                      PRIVATE TOUR Balboa Park
# 28    59                               Disneyland Tour
# 29    44               Carlsbad Marathon Half Marathon
# ..   ...                                           ...
# 250  189                      San Diego Dinner Cruises
# 251   84                        Gaslamp Artisan Market
# 252  174                                      Platform
# 253  265    Valley Center Western Days  Stampede Rodeo
# 254  159           Old Town Tequila and Tortillas Tour
# 255   53               Coronado Bay and the Beach Tour
# 256  250             The WorldFamous Winery Train Tour
# 257  144               Mermaid Half Marathon San Diego
# 258   38              Cabrillo Sunrise K Fun Run  Walk
# 259    9                            Belmonty's Burgers
# 260   95                             The Patio Express
# 261   50                     Newport Pizza & Ale House
# 262  136                              Thrusters Lounge
# 263   52                            Johnny V San Diego
# 264   22                            Bub's at the Beach
# 265  109                  San Diego Motorsports Rental
# 266   89                       Pacific Beach Bike Shop
# 267  100                            Resort Watersports
# 268   15                   Beach House Bikes & Rentals
# 269  145                               Wings Beachwear
# 270  102             Rocket Fizz Soda Pop & Candy Shop
# 271   23                              Buffalo Exchange
# 272  135                              Therapie Day Spa
# 273  115                        School of Healing Arts
# 274  121                                    Spa Brezza
# 275   61                               Le Vie Skincare
# 276  101                                 Riffs Studios
# 277   46       Happy Head Foot Reflexology and Massage
# 278   58                                La Vie Day Spa
# 279   26                             Capehart Dog Park
#
#                                                Address  \
# 0      2211 Pacific Beach Dr, San Diego, CA 92109-5626
# 1             745 Isthmus Ct, San Diego, CA 92109-7785
# 2             4208 Oliver Ct, San Diego, CA 92109-3957
# 3          1908 Dana Landing Road, San Diego, CA 92109
# 4            1441 Quivira Rd, San Diego, CA 92109-7805
# 5            1788 Garnet Ave, San Diego, CA 92109-3350
# 6    4150 Mission Blvd Suite 161, San Diego, CA 921...
# 7                                                 None
# 8                                                 None
# 9                                                 None
# 10                                                None
# 11                                                None
# 12                                                None
# 13                                                None
# 14                                                None
# 15                                                None
# 16                                                None
# 17                                                None
# 18                                                None
# 19                                                None
# 20                                                None
# 21                                                None
# 22                                                None
# 23                                                None
# 24                                                None
# 25                                                None
# 26                                                None
# 27                                                None
# 28                                                None
# 29                                                None
# ..                                                 ...
# 250                                               None
# 251                                               None
# 252                                               None
# 253                                               None
# 254                                               None
# 255                                               None
# 256                                               None
# 257                                               None
# 258                                               None
# 259                                  3146 Mission Blvd
# 260                                  3415 Mission Blvd
# 261                                   5050 Newport Ave
# 262        4633 Mission Blvd, San Diego, CA 92109-2733
# 263           945 Garnet Ave, San Diego, CA 92109-2729
# 264          1030 Garnet Ave, San Diego, CA 92109-2833
# 265      4275 Mission Bay Dr, San Diego, CA 92109-5727
# 266  4305 Mission Blvd Ste 101, San Diego, CA 92109...
# 267        3981 Mission Blvd, San Diego, CA 92109-6958
# 268     4629 Cass St Ste 202, San Diego, CA 92109-2805
# 269        3136 Mission Blvd, San Diego, CA 92109-7778
# 270          1414 Garnet Ave, San Diego, CA 92109-3014
# 271  1007 Garnet Ave Pacific Beach, San Diego, CA 9...
# 272         4985 Voltaire St, San Diego, CA 92107-2105
# 273  1001 Garnet Ave Ste 200, San Diego, CA 92109-2850
# 274   1775 E Mission Bay Dr , San Diego, CA 92109-6801
# 275  7661 Girard Ave Suite 100, La Jolla, San Diego...
# 276  5510 La Jolla Blvd, La Jolla, San Diego, CA 92037
# 277           953 Garnet Ave, San Diego, CA 92109-2729
# 278  7532 La Jolla Blvd, La Jolla, San Diego, CA 92...
# 279         4754 Soledad Mtn Road, San Diego, CA 92109
#
#                                            Description  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# 5                                                 None
# 6                                                 None
# 7                                       (Not Provided)
# 8                                       (Not Provided)
# 9         Beaches, Local Eats, Drinks, and Sightseeing
# 10                                      (Not Provided)
# 11                                      (Not Provided)
# 12                   During the Farmers Insurance Open
# 13                                      (Not Provided)
# 14                                  3-course prix fixe
# 15         Night fishing events throughout the summer!
# 16                                    30th Anniversary
# 17                           It’s going to be AWESOME!
# 18                                      (Not Provided)
# 19                                      (Not Provided)
# 20   Immersive Exhibit of Survival Stories&Photographs
# 21                                      (Not Provided)
# 22             Presented by the Center for World Music
# 23                                      (Not Provided)
# 24           Weeklong Festival of Food, Wine + Culture
# 25                                      (Not Provided)
# 26                                      (Not Provided)
# 27                Historic Highlights and Secret Spots
# 28                                      from San Diego
# 29                                      (Not Provided)
# ..                                                 ...
# 250  One of San Diego's most scenic Dining Experiences
# 251    Every Sunday at Fifth Avenue and Market Street!
# 252                   Recontextualizing the Still Life
# 253                                     (Not Provided)
# 254     Explore San Diego's most historic neighborhood
# 255  Cruise to the luxe life in this unique beach town
# 256                           Ranked #2 in the World!*
# 257                                     (Not Provided)
# 258                                     (Not Provided)
# 259                                            Burgers
# 260                                              Cafes
# 261                                              Pizza
# 262                                               None
# 263                                               None
# 264                                               None
# 265                                               None
# 266                                               None
# 267                                               None
# 268                                               None
# 269                                               None
# 270                                               None
# 271                                               None
# 272                                               None
# 273                                               None
# 274                                               None
# 275                                               None
# 276                                               None
# 277                                               None
# 278                                               None
# 279                                               None
#
#                       Category     Neighborhood  Cost        Date  Reviews
# 0    Boat Tours & Water Sports             None     3        None      2.0
# 1    Boat Tours & Water Sports             None     3        None      2.0
# 2    Boat Tours & Water Sports             None     2        None      2.0
# 3    Boat Tours & Water Sports             None     3        None      2.0
# 4    Boat Tours & Water Sports             None     2        None      2.0
# 5          Classes & Workshops             None     3        None      2.0
# 6          Classes & Workshops             None     3        None      2.0
# 7                       Events   Mission Valley     2        None      NaN
# 8                       Events         Downtown     2  2019-01-13      NaN
# 9                       Events        City-wide     2        None      NaN
# 10                      Events    North Coastal     2  2019-03-01      NaN
# 11                      Events         Coronado     2  2019-07-15      NaN
# 12                      Events         La Jolla     2  2019-09-04      NaN
# 13                      Events         Downtown     2        None      NaN
# 14                      Events      Mission Bay     2  2019-02-14      NaN
# 15                      Events      East County     2  2019-08-22      NaN
# 16                      Events      East County     2  2019-07-31      NaN
# 17                      Events    North Coastal     2  2019-07-12      NaN
# 18                      Events         Downtown     2        None      NaN
# 19                      Events    North Coastal     2  2019-02-09      NaN
# 20                      Events         Downtown     2  2019-01-07      NaN
# 21                      Events         La Jolla     2        None      NaN
# 22                      Events         La Jolla     2  2019-01-26      NaN
# 23                      Events       Point Loma     2  2019-05-16      NaN
# 24                      Events        City-wide     2  2019-12-21      NaN
# 25                      Events    North Coastal     2  2019-07-04      NaN
# 26                      Events         Downtown     2  2019-01-13      NaN
# 27                      Events      Balboa Park     3        None      NaN
# 28                      Events         Downtown     2        None      NaN
# 29                      Events    North Coastal     2  2019-01-20      NaN
# ..                         ...              ...   ...         ...      ...
# 250                     Events         Downtown     2  2019-01-10      NaN
# 251                     Events  Gaslamp Quarter     2        None      NaN
# 252                     Events         Downtown     2        None      NaN
# 253                     Events        City-wide     2  2019-05-25      NaN
# 254                     Events   Mission Valley     2        None      NaN
# 255                     Events        City-wide     2        None      NaN
# 256                     Events         La Jolla     2  2019-01-09      NaN
# 257                     Events      Mission Bay     2  2019-02-09      NaN
# 258                     Events       Point Loma     2  2019-02-09      NaN
# 259               Food & Drink             None     2        None      2.0
# 260               Food & Drink             None     3        None      2.0
# 261               Food & Drink             None     2        None      2.0
# 262                  Nightlife             None     2        None      1.0
# 263                  Nightlife             None     2        None      1.0
# 264                  Nightlife             None     2        None      1.0
# 265         Outdoor Activities             None     2        None      3.0
# 266         Outdoor Activities             None     2        None      2.0
# 267         Outdoor Activities             None     2        None      2.0
# 268         Outdoor Activities             None     3        None      1.0
# 269                   Shopping             None     2        None      1.0
# 270                   Shopping             None     3        None      1.0
# 271                   Shopping             None     3        None      2.0
# 272            Spas & Wellness             None     2        None      2.0
# 273            Spas & Wellness             None     3        None      2.0
# 274            Spas & Wellness             None     3        None      2.0
# 275            Spas & Wellness             None     2        None      2.0
# 276            Spas & Wellness             None     3        None      2.0
# 277            Spas & Wellness             None     3        None      2.0
# 278            Spas & Wellness             None     2        None      2.0
# 279               Things to do             None     3        None      4.0
#
# [280 rows x 9 columns]

# %%
#Confirm data has been added by querying the events table
pd.read_sql_query('select * from events', con=engine).head()
# Out:
#    id                                          Name Address  \
# 0   1  15th Annual Martin Luther King Jr Day Parade    None
# 1   2  18th Annual St Patricks Day Parade  Festival    None
# 2   3            3rd Annual San Diego Bird Festival    None
# 3   4    4th Annual International Mariachi Festival    None
# 4   5                   4th Annual Small Image Show    None
#
#                                          Description Category Neighborhood  \
# 0                                     (Not Provided)   Events     Downtown
# 1                                     (Not Provided)   Events  Balboa Park
# 2                                     (Not Provided)   Events  Mission Bay
# 3                                     (Not Provided)   Events    South Bay
# 4  Art Exhibition Featuring Works 10x10" and Smaller   Events     Downtown
#
#    Cost        Date Reviews
# 0     2  2019-01-20    None
# 1     1  2019-03-16    None
# 2     2  2019-05-12    None
# 3     2  2019-03-10    None
# 4     2  2019-04-21    None

# %%
#Confirm data has been added by querying the events table
pd.read_sql_query('select * from attractions', con=engine).head()
# Out:
#    id                       Name  \
# 0   1       Action Sport Rentals
# 1   2     Adventure Water Sports
# 2   3     Adventure Water Sports
# 3   4   Affordable Jet Ski Tours
# 4   5  Always Summer Surf School
#
#                                              Address Description  \
# 0        3981 Mission Blvd, San Diego, CA 92109-6958        None
# 1  1710 W Mission Bay Dr Dana Hotel, San Diego, C...        None
# 2    2211 Pacific Beach Dr, San Diego, CA 92109-5626        None
# 3      4255 Mission Bay Dr, San Diego, CA 92109-5782        None
# 4          4904 Crystal Dr, San Diego, CA 92109-2062        None
#
#                     Category Neighborhood  Reviews  Date  Cost
# 0  Boat Tours & Water Sports         None       18  None     2
# 1  Boat Tours & Water Sports         None        7  None     2
# 2  Boat Tours & Water Sports         None        1  None     2
# 3  Boat Tours & Water Sports         None        1  None     2
# 4  Boat Tours & Water Sports         None        8  None     2

# %%
#Confirm data has been added by querying the events table
pd.read_sql_query('select * from restaurants', con=engine).head()
# Out:
#    id                   Name                 Address     Description  \
# 0   1         Arslan's Gyros       3861 Mission Blvd           Greek
# 1   2  BBQ House Bar & Grill        5025 Newport Ave            Bars
# 2   3  BO-beau kitchen + bar  4996 W Point Loma Blvd          French
# 3   4              Bao Beach       3735 Mission Blvd    Asian Fusion
# 4   5   Barefoot Bar & Grill        1404 Vacation Rd  American (New)
#
#        Category Neighborhood  Reviews  Date  Cost
# 0  Food & Drink         None      322  None     2
# 1  Food & Drink         None       23  None     2
# 2  Food & Drink         None        6  None     4
# 3  Food & Drink         None       36  None     2
# 4  Food & Drink         None     1526  None     3

# %%
#Confirm data has been added by querying the events, attractions and restaurants tables
pd.read_sql_query('select * from events union select * from attractions union select * from restaurants\
    order by Name;', con=engine).head()
# Out:
#    id                                          Name Address  \
# 0   1  15th Annual Martin Luther King Jr Day Parade    None
# 1   2  18th Annual St Patricks Day Parade  Festival    None
# 2   3            3rd Annual San Diego Bird Festival    None
# 3   4    4th Annual International Mariachi Festival    None
# 4   5                   4th Annual Small Image Show    None
#
#                                          Description Category Neighborhood  \
# 0                                     (Not Provided)   Events     Downtown
# 1                                     (Not Provided)   Events  Balboa Park
# 2                                     (Not Provided)   Events  Mission Bay
# 3                                     (Not Provided)   Events    South Bay
# 4  Art Exhibition Featuring Works 10x10" and Smaller   Events     Downtown
#
#    Cost        Date  Reviews
# 0     2  2019-01-20      NaN
# 1     1  2019-03-16      NaN
# 2     2  2019-05-12      NaN
# 3     2  2019-03-10      NaN
# 4     2  2019-04-21      NaN

# %%
pd.read_sql_query('select * from (select * from events union select * from attractions union select * from restaurants) as a \
where a.Category = "Food & Drink" order by a.Name;', con=engine).head()
# Out:
#    id                  Name                                     Address  \
# 0   1        Arslan's Gyros                           3861 Mission Blvd
# 1  11     Baja Winery Tours  4629 Cass St # 2, San Diego, CA 92109-2805
# 2   4             Bao Beach                           3735 Mission Blvd
# 3   5  Barefoot Bar & Grill                            1404 Vacation Rd
# 4   6       Bayside Landing                            3780 Ingraham St
#
#       Description      Category Neighborhood  Cost  Date  Reviews
# 0           Greek  Food & Drink         None   322  None        2
# 1            None  Food & Drink         None   172  None        3
# 2    Asian Fusion  Food & Drink         None    36  None        2
# 3  American (New)  Food & Drink         None  1526  None        3
# 4  American (New)  Food & Drink         None   236  None        3
